# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import gmaps
import gmaps.geojson_geometries
import os
import json
import requests
import pprint as pp



# Import API key
from config import g_key

# %%
# File to Load
NYC1_data_to_load = "resources/NYC_Listings1.csv"
NYC2_data_to_load = "resources/NYC_Listings2.csv"
NYC3_data_to_load = "resources/NYC_Listings3.csv"

# Read School and Student Data File and store into Pandas Data Frames
NYC1_data = pd.read_csv(NYC1_data_to_load)
NYC2_data = pd.read_csv(NYC2_data_to_load)
NYC3_data = pd.read_csv(NYC3_data_to_load)

# %%
# Create a full NYC DF
NYC_data = pd.concat([NYC1_data, NYC2_data, NYC3_data], ignore_index=True)
NYC_data.head()
# Out:
#      id                        listing_url     scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  2.019080e+13       8/7/19
# 1  3647  https://www.airbnb.com/rooms/3647  2.019080e+13       8/6/19
# 2  3831  https://www.airbnb.com/rooms/3831  2.019080e+13       8/6/19
# 3  5022  https://www.airbnb.com/rooms/5022  2.019080e+13       8/6/19
# 4  5099  https://www.airbnb.com/rooms/5099  2.019080e+13       8/6/19
#
#                                                name  \
# 0                             Skylit Midtown Castle
# 1               THE VILLAGE OF HARLEM....NEW YORK !
# 2                   Cozy Entire Floor of Brownstone
# 3  Entire Apt: Spacious Studio/Loft by central park
# 4         Large Cozy 1 BR Apartment In Midtown East
#
#                                              summary  \
# 0  Find your romantic getaway to this beautiful, ...
# 1                                                NaN
# 2  Urban retreat: enjoy 500 s.f. floor in 1899 br...
# 3                                                NaN
# 4  My large 1 bedroom apartment is true New York ...
#
#                                                space  \
# 0  - Spacious (500+ft²), immaculate and nicely fu...
# 1  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...
# 2  Greetings!      We own a double-duplex brownst...
# 3  Loft apartment with high ceiling and wood floo...
# 4  I have a large 1 bedroom apartment centrally l...
#
#                                          description experiences_offered  \
# 0  Find your romantic getaway to this beautiful, ...                none
# 1  WELCOME TO OUR INTERNATIONAL URBAN COMMUNITY T...                none
# 2  Urban retreat: enjoy 500 s.f. floor in 1899 br...                none
# 3  Loft apartment with high ceiling and wood floo...                none
# 4  My large 1 bedroom apartment is true New York ...                none
#
#                                neighborhood_overview        ...          \
# 0  Centrally located in the heart of Manhattan ju...        ...
# 1                                                NaN        ...
# 2  Just the right mix of urban center and local n...        ...
# 3                                                NaN        ...
# 4  My neighborhood in Midtown East is called Murr...        ...
#
#   instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                f                        f  strict_14_with_grace_period
# 1                f                        f  strict_14_with_grace_period
# 2                f                        f                     moderate
# 3                f                        f  strict_14_with_grace_period
# 4                f                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             t                                t
# 1                             t                                t
# 2                             f                                f
# 3                             t                                t
# 4                             t                                t
#
#    calculated_host_listings_count  \
# 0                             2.0
# 1                             1.0
# 2                             1.0
# 3                             1.0
# 4                             1.0
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          1.0
# 1                                          0.0
# 2                                          1.0
# 3                                          1.0
# 4                                          1.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          1.0
# 2                                          0.0
# 3                                          0.0
# 4                                          0.0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                          1.0               0.39
# 1                                          0.0                NaN
# 2                                          0.0               4.64
# 3                                          0.0               0.10
# 4                                          0.0               0.60
#
# [5 rows x 106 columns]

# %%
# Review columns
column_names = list(NYC_data.columns)
column_names[:5]
# Out:
# ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name']

# %%
# Select Columns for clean DataFrame
Clean_NYC = NYC_data[['id','name','neighbourhood',
                      'latitude','longitude','property_type',
                      'room_type','accommodates','amenities',
                      'price','availability_365','number_of_reviews',
                     'number_of_reviews_ltm','review_scores_rating',
                      'review_scores_location','reviews_per_month']]
# Drop null values
Clean_NYC = Clean_NYC.dropna()

# Change price value to float
Clean_NYC['price'] = Clean_NYC['price'].map(lambda x: x.lstrip('$'))
#Clean_NYC['price'] = Clean_NYC['price'].map(lambda x: x.lstrip(','))
Clean_NYC['price'] = Clean_NYC['price'].map(lambda x: x.replace(',',''))
Clean_NYC['price'] = Clean_NYC['price'].astype('float')

# Preview DataFrame
Clean_NYC
# Out:
#              id                                               name  \
# 0          2595                              Skylit Midtown Castle
# 2          3831                    Cozy Entire Floor of Brownstone
# 3          5022   Entire Apt: Spacious Studio/Loft by central park
# 4          5099          Large Cozy 1 BR Apartment In Midtown East
# 5          5121                                    BlissArtsSpace!
# 6          5178                   Large Furnished Room Near B'way
# 7          5203                 Cozy Clean Guest Room - Family Apt
# 8          5222                                      Best Hideaway
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm
# 10         5295                   Beautiful 1br on Upper West Side
# 11         5441                    Central Manhattan/near Broadway
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental
# 13         6090                      West Village Nest - Superhost
# 14         6848                   Only 2 stops to Manhattan studio
# 15         7097                  Perfect for Your Parents + Garden
# 16         7322   Chelsea Perfect  by Doti, an AIRBNB  Super Host!
# 17         7726    Hip Historic Brownstone Apartment with Backyard
# 19         7801                   Sweet and Spacious Brooklyn Loft
# 20         8024                     CBG CtyBGd HelpsHaiti rm#1:1-4
# 21         8110                              CBG Helps Haiti Rm #2
# 22         8490             MAISON DES SIRENES1,bohemian apartment
# 23         8505                 Sunny Bedroom Across Prospect Park
# 25         9357                               Midtown Pied-a-terre
# 26         9657                   Modern 1 BR / NYC / EAST VILLAGE
# 27         9668                              front room/double bed
# 28         9704                Spacious 1 bedroom in luxe building
# 29         9782                  Loft in Williamsburg Area w/ Roof
# 30         9783                                back room/bunk beds
# 31        10452                              Large B&B Style rooms
# 32        10962    Lovely room 2 & garden; Best area, Legal rental
# ...         ...                                                ...
# 40141  32050937                         Downtown Williamsburg Loft
# 40142  32050983       Hudson River/GW Bridge  View. Spacious  Room
# 40143  32053614                           TINY ROOM FOR ONE PERSON
# 40145  32059283                   Sun-drenched and Spacious Studio
# 40146  32062178                                Unique Holiday Home
# 40147  32062843  Cute renovated apartment in the heart of flush...
# 40148  32064131                     Cozy Brooklyn Studio available
# 40149  32064173     Safe, cozy, and clean in the heart of Brooklyn
# 40150  32064705       Spacious private bedroom in Hamilton Heights
# 40151  32065845  Times Square Suite with amazing views, high fl...
# 40153  32069538                                 Harlem Residence 2
# 40154  32069686  Amazing views, sun, luxe style, live like a lo...
# 40155  32070946         Amazing Studio at the Time Square Area/54D
# 40149            Flatbush  40.65441  -73.95024           Apartment
# 40150           Manhattan  40.82051  -73.95291           Apartment
# 40151           Manhattan  40.76015  -73.98497  Serviced apartment
# 40153           Manhattan  40.83325  -73.94444           Apartment
# 40154            Brooklyn  40.71396  -73.93986           Apartment
# 40155      Hell's Kitchen  40.76318  -73.99335           Apartment
# 40156     Lower East Side  40.72233  -73.99334           Apartment
# 40157     Upper East Side  40.77698  -73.95712           Apartment
# 40158              Queens  40.73210  -73.89712           Apartment
# 40159            Glendale  40.69271  -73.89519           Apartment
# 40160            Brooklyn  40.71268  -73.94720           Apartment
# 40162     Upper West Side  40.79481  -73.97432           Apartment
# 40163              Queens  40.73641  -73.92415           Townhouse
# 40164              Queens  40.70484  -73.91393           Apartment
# 40167  Bedford-Stuyvesant  40.67767  -73.91784           Apartment
# 40169  Bedford-Stuyvesant  40.68272  -73.92555           Apartment
# 40170              Queens  40.74523  -73.83321               House
# 40171            Flushing  40.74588  -73.83284               House
# 40172      Williamsbridge  40.87905  -73.85243         Guest suite
# 40173           Chinatown  40.71214  -73.99643           Apartment
# 40174           Manhattan  40.71247  -73.99619           Apartment
# 40175           Manhattan  40.71208  -73.99410           Apartment
# 40176             Midtown  40.74670  -73.98706           Apartment
#
#              room_type  accommodates  \
# 0      Entire home/apt           2.0
# 2      Entire home/apt           3.0
# 3      Entire home/apt           1.0
# 4      Entire home/apt           2.0
# 5         Private room           2.0
# 6         Private room           2.0
# 7         Private room           1.0
# 8      Entire home/apt           2.0
# 9      Entire home/apt           3.0
# 10     Entire home/apt           2.0
# 11        Private room           2.0
# 12        Private room           2.0
# 13     Entire home/apt           1.0
# 14     Entire home/apt           3.0
# 15     Entire home/apt           4.0
# 16        Private room           3.0
# 17     Entire home/apt           4.0
# 19     Entire home/apt           4.0
# 20        Private room           4.0
# 21        Private room           3.0
# 22     Entire home/apt           5.0
# 23        Private room           2.0
# 25     Entire home/apt           2.0
# 26     Entire home/apt           3.0
# 27        Private room           2.0
# 28        Private room           2.0
# 29        Private room           2.0
# 30        Private room           2.0
# 31        Private room           3.0
# 32        Private room           2.0
# ...                ...           ...
# 40141  Entire home/apt           6.0
# 40142     Private room           3.0
# 40143     Private room           1.0
# 40145  Entire home/apt           1.0
# 40146     Private room           2.0
# 40147  Entire home/apt           4.0
# 40148  Entire home/apt           3.0
# 40149     Private room           2.0
# 40150     Private room           2.0
# 40151  Entire home/apt           7.0
# 40153     Private room           2.0
# 40154  Entire home/apt           5.0
# 40155  Entire home/apt           2.0
# 40156     Private room           2.0
# 40157  Entire home/apt           8.0
# 40158     Private room           1.0
# 40159  Entire home/apt           6.0
# 40160     Private room           2.0
# 40162  Entire home/apt           7.0
# 40163     Private room           1.0
# 40164     Private room           2.0
# 40167     Private room           4.0
# 40169  Entire home/apt           3.0
# 40170     Private room           2.0
# 40171     Private room           2.0
# 40172  Entire home/apt           2.0
# 40173     Private room           2.0
# 40174     Private room           2.0
# 40175     Private room           2.0
# 40176  Entire home/apt           3.0
#
#                                                amenities  price  \
# 0      {TV,Wifi,"Air conditioning",Kitchen,"Paid park...  225.0
# 2      {TV,"Cable TV",Internet,Wifi,"Air conditioning...   89.0
# 3      {Internet,Wifi,"Air conditioning",Kitchen,Elev...   80.0
# 4      {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...  200.0
# 5      {Wifi,"Air conditioning",Kitchen,"Pets live on...   60.0
# 6      {TV,Wifi,"Air conditioning","Paid parking off ...   79.0
# 7      {Internet,Wifi,"Air conditioning","Paid parkin...   79.0
# 8      {TV,"Cable TV",Internet,Wifi,"Air conditioning...  116.0
# 9      {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  150.0
# 10     {Internet,Wifi,"Air conditioning",Kitchen,Door...  135.0
# 11     {Internet,Wifi,"Air conditioning",Breakfast,"B...   85.0
# 12     {Internet,Wifi,"Air conditioning","Free street...   89.0
# 13     {Wifi,"Air conditioning",Kitchen,Heating,"Smok...  120.0
# 14     {TV,Wifi,"Air conditioning",Kitchen,"Free stre...  140.0
# 15     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  215.0
# 16     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  140.0
# 17     {TV,Internet,Wifi,"Air conditioning",Kitchen,"...   99.0
# 19     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  299.0
# 20     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  115.0
# 21     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  110.0
# 22     {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  120.0
# 23     {Wifi,"Air conditioning","Free street parking"...   60.0
# 25     {TV,Wifi,"Air conditioning",Kitchen,"Pets allo...  150.0
# 26     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  180.0
# 27     {Internet,Wifi,Pool,Kitchen,"Paid parking off ...   50.0
# 28     {TV,"Cable TV",Internet,Wifi,"Air conditioning...   52.0
# 29     {TV,Internet,Wifi,"Air conditioning",Kitchen,"...   55.0
# 30     {Internet,Wifi,"Air conditioning",Pool,Kitchen...   50.0
# 31     {TV,"Cable TV",Internet,Wifi,"Air conditioning...   70.0
# 32     {Internet,Wifi,"Air conditioning","Paid parkin...   89.0
# ...                                                  ...    ...
# 40141  {TV,Wifi,"Air conditioning",Kitchen,"Paid park...  200.0
# 40142  {TV,"Cable TV",Wifi,Kitchen,"Paid parking off ...   85.0
# 40143  {Wifi,"Air conditioning",Kitchen,"Free street ...   35.0
# 40145  {Wifi,"Air conditioning",Kitchen,Heating,"Smok...   85.0
# 40146  {TV,Wifi,"Air conditioning",Kitchen,Breakfast,...   50.0
# 40147  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  105.0
# 40148  {Wifi,"Air conditioning",Kitchen,"Pets allowed...   60.0
# 40149  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...   31.0
# 40150  {Wifi,"Air conditioning",Kitchen,Gym,Breakfast...   53.0
# 40151  {TV,Wifi,"Air conditioning",Kitchen,"Paid park...  890.0
# 40153  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...   50.0
# 40154  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  179.0
# 40155  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  130.0
# 40156  {Wifi,"Air conditioning",Kitchen,"Fire extingu...   85.0
# 40157  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...  800.0
# 40158  {Wifi,"Air conditioning","Free street parking"...   40.0
# 40159  {TV,Wifi,"Air conditioning",Kitchen,"Free park...  135.0
# 40160  {TV,Wifi,"Air conditioning",Kitchen,Heating,"S...   80.0
# 40162  {TV,Wifi,"Air conditioning",Elevator,"Indoor f...  150.0
# 40163  {Wifi,"Air conditioning",Kitchen,Breakfast,Hea...   40.0
# 40164  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen
# 40176             287.0                6.0                    6.0
#
#        review_scores_rating  review_scores_location  reviews_per_month
# 0                      95.0                    10.0               0.39
# 2                      90.0                    10.0               4.64
# 3                      93.0                     9.0               0.10
# 4                      89.0                     9.0               0.60
# 5                      90.0                     9.0               0.39
# 6                      84.0                    10.0               3.48
# 7                      98.0                    10.0               0.98
# 8                      95.0                    10.0               0.74
# 9                      94.0                     9.0               1.33
# 10                     93.0                     9.0               0.42
# 11                     97.0                    10.0               1.50
# 12                     94.0                    10.0               1.33
# 13                     97.0                    10.0               0.22
# 14                     91.0                     9.0               1.24
# 15                     97.0                    10.0               1.72
# 16                     96.0                    10.0               2.17
# 17                     96.0                    10.0               4.59
# 19                     98.0                    10.0               0.07
# 20                     93.0                    10.0               1.09
# 21                     91.0                    10.0               0.63
# 22                     95.0                     9.0               0.76
# 23                     97.0                    10.0               1.35
# 25                     90.0                    10.0               0.48
# 26                     93.0                    10.0               0.24
# 27                     87.0                     9.0               2.04
# 28                     98.0                    10.0               1.46
# 29                     81.0                     9.0               1.67
# 30                     89.0                     9.0               2.35
# 31                     94.0                     9.0               0.65
# 32                     95.0                    10.0               1.41
# ...                     ...                     ...                ...
# 40141                 100.0                    10.0               4.03
# 40142                 100.0                    10.0               2.02
# 40143                  95.0                    10.0               4.20
# 40145                 100.0                     8.0               0.37
# 40146                  96.0                     9.0               1.99
# 40147                  93.0                     9.0               4.38
# 40148                  84.0                     8.0               0.93
# 40149                  98.0                    10.0               4.21
# 40150                  96.0                     9.0               0.88
# 40151                 100.0                    10.0               0.34
# 40153                  96.0                    10.0               2.84
# 40154                  96.0                    10.0               2.31
# 40155                 100.0                    10.0               0.41
# 40156                  84.0                     9.0               3.91
# 40157                 100.0                    10.0               0.90
# 40158                 100.0                     8.0               1.00
# 40159                 100.0                    10.0               2.01
# 40160                 100.0                    10.0               3.05
# 40162                  87.0                    10.0               4.41
# 40163                  93.0                    10.0               1.22
# 40164                  95.0                     9.0               4.36
# 40167                  91.0                     9.0               1.47
# 40169                 100.0                     9.0               2.38
# 40170                  88.0                     9.0               4.06
# 40171                  97.0                     9.0               3.65
# 40172                  97.0                     9.0               3.35
# 40173                  94.0                    10.0               5.74
# 40174                  93.0                     9.0               4.29
# 40175                  88.0                     9.0               5.27
# 40176                  87.0                    10.0               1.29
#
# [32676 rows x 16 columns]

# %%
# GroupBY Neighborhood
neighborhoods_ratings = Clean_NYC.groupby('neighbourhood')['review_scores_location'].mean()
neighborhoods_ratings.sort_values(ascending=False, inplace=True)
neighborhoods_ratings
# USE GOOGLE PLACES API TO CREATE A MAP THATS SPLIT
# Out:
# neighbourhood
# Times Square/Theatre District    10.000000
# Grant City                       10.000000
# City Island                      10.000000
# Oakwood                          10.000000
# Woodlawn                         10.000000
# Todt Hill                        10.000000
# Lighthouse HIll                  10.000000
# Huguenot                         10.000000
# Castleton Corners                10.000000
# Union Square                     10.000000
# Noho                             10.000000
# Hillcrest                        10.000000
# DUMBO                            10.000000
# Brooklyn Heights                 10.000000
# New Dorp Beach                   10.000000
# Silver Lake                      10.000000
# Hudson Square                    10.000000
# Little Italy                     10.000000
# Battery Park City                10.000000
# New Brighton                     10.000000
# Westerleigh                      10.000000
# Dongan Hills                     10.000000
# Annadale                         10.000000
# Fresh Meadows                    10.000000
# Eltingville                      10.000000
# Meatpacking District             10.000000
# Tribeca                           9.970588
# Flatiron District                 9.968254
# West Village                      9.962185
# Greenwich Village                 9.956989
#                                    ...
# Lindenwood                        9.000000
# Elm Park                          9.000000
# West Farms                        9.000000
# Meiers Corners                    9.000000
# Melrose                           9.000000
# Randall Manor                     9.000000
# Country Club                      9.000000
# Bergen Beach                      9.000000
# Van Nest                          9.000000
# Stapleton                         9.000000
# Morris Heights                    9.000000
# New Springville                   9.000000
# Graniteville                      9.000000
# Tottenville                       9.000000
# Morrisania                        9.000000
# Red Hook                          8.965517
# Brownsville                       8.928571
# Port Morris                       8.900000
# Maspeth                           8.896552
# Highbridge                        8.894737
# Mott Haven                        8.884615
# East New York                     8.854962
# Tremont                           8.769231
# Bensonhurst                       8.740741
# Norwood                           8.714286
# Mariners Harbor                   8.666667
# Kingsbridge Heights               8.600000
# Hunts Point                       8.500000
# Midland Beach                     8.000000
# Arrochar                          8.000000
# Name: review_scores_location, Length: 190, dtype: float64

# %%
neighborhoods_list = list(neighborhoods.index)
neighborhoods_list[:10]
# Out:
# ['Allerton',
#  'Alphabet City',
#  'Annadale',
#  'Arrochar',
#  'Astoria',
#  'Bath Beach',
#  'Battery Park City',
#  'Bay Ridge',
#  'Baychester',
#  'Bayside']

# %%
# Create a Dictionary with neighbourhood DataFrames
d = {}
for city in neighborhoods_list:
    checker = (Clean_NYC['neighbourhood'] == city)
    city_df = Clean_NYC.where(checker)
    city_df = city_df.dropna()
    d[city] = city_df

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)
# Create a Gmaps figure
fig = gmaps.figure()

locations = Clean_NYC[['latitude','longitude']]
weights = Clean_NYC['review_scores_location']
# Create the Heat Layer Object 
heat_layer = gmaps.heatmap_layer(locations=locations, weights=weights, dissipating=True)
heat_layer.point_radius = 4
heat_layer.gradient = [
    'gray',
    'black',
    'blue'
]
# Add Heat Layer to Figure
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
new_york_coordinates = (40.75, -74.00)
#gmaps.figure(center=new_york_coordinates, zoom_level=12)

countries_geojson = gmaps.geojson_geometries.load_geometry('us-counties')

fig = gmaps.figure(center=new_york_coordinates, zoom_level=12)
gini_layer = gmaps.geojson_layer(countries_geojson)
fig.add_layer(gini_layer)
#fig

# %%
gmaps.geojson_geometries.list_geometries()
# Out:
# dict_keys(['countries', 'countries-high-resolution', 'england-counties', 'us-states', 'us-counties', 'india-states', 'brazil-states'])

# %%
# NEIGHBORHOOD OVERLAY 

with open('resources/custom-pedia-cities-nyc-Mar2018.json') as f:
    geometry = json.load(f)

fig = gmaps.figure()
geojson_layer = gmaps.geojson_layer(geometry)
fig.add_layer(geojson_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
