# %%
# Dependencies and Setup
import pandas as pd

# File to Load
NYC1_data_to_load = "resources/NYC_Listings1.csv"
NYC2_data_to_load = "resources/NYC_Listings2.csv"
NYC3_data_to_load = "resources/NYC_Listings3.csv"

SF_data_to_load = "resources/SF_Listings.csv"

# Read School and Student Data File and store into Pandas Data Frames
NYC1_data = pd.read_csv(NYC1_data_to_load)
NYC2_data = pd.read_csv(NYC2_data_to_load)
NYC3_data = pd.read_csv(NYC3_data_to_load)


SF_data = pd.read_csv(SF_data_to_load)

# Combine the data into a single dataset
##airbnb_data_complete = pd.merge(NYC_data, SF_data, how="leftORright", on=["column1", "column2"])
# Out:
# /Users/mikeyesteban/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mikeyesteban/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (94) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/mikeyesteban/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (61,62,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create a full NYC DF
NYC_data = pd.concat([NYC1_data, NYC2_data, NYC3_data], ignore_index=True)
# ADD state columns to NYC and SF data
NYC_data['state'] = 'NY'
SF_data['state'] = 'SF'

# Concatenate NYC an
airbnb_data = pd.concat([NYC_data, SF_data], ignore_index=True)
airbnb_data.groupby('state').mean()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# state
# NY     1.604620e+07  2.019080e+13            NaN         NaN             NaN
# SF     1.901005e+07  2.019081e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# state
# NY     5.232186e+07                   NaN            12.800383
# SF     5.479076e+07                   NaN            80.686798
#
#        host_total_listings_count   latitude        ...          \
# state                                              ...
# NY                     12.800383  40.728549        ...
# SF                     80.686798  37.766142        ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# state
# NY                      9.271086               9.762254
# SF                      9.625100               9.859325
#
#        review_scores_communication  review_scores_location  \
# state
# NY                        9.771765                9.560585
# SF                        9.835958                9.686174
#
#        review_scores_value  calculated_host_listings_count  \
# state
# NY                9.403425                        5.113816
# SF                9.403859                       22.088983
#
#        calculated_host_listings_count_entire_homes  \
# state
# NY                                        3.644118
# SF                                       18.463296
#
#        calculated_host_listings_count_private_rooms  \
# state
# NY                                         1.376913
# SF                                         3.028086
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# state
# NY                                        0.092785           1.193607
# SF                                        0.597600           1.847225
#
# [2 rows x 43 columns]

# %%
# Review columns
column_names = list(NYC_data.columns)

# %%
# Select Columns for clean DataFrame
NYC_data['host_neighbourhood']
NYC_data['latitude']
NYC_data['longitude']
NYC_data['property_type']
NYC_data['room_type']
NYC_data['accommodates']
NYC_data['amenities']
NYC_data['price']
NYC_data['availability_365']
NYC_data['number_of_reviews']
NYC_data['number_of_reviews_ltm']
NYC_data['review_scores_rating']
NYC_data['review_scores_location']
NYC_data['reviews_per_month']

Clean_NYC = NYC_data[['host_neighbourhood','latitude','longitude',
                      'property_type','room_type','accommodates',
                     'amenities','price','availability_365','number_of_reviews',
                     'number_of_reviews_ltm','review_scores_rating',
                      'review_scores_location','reviews_per_month']]
Clean_NYC
# Out:
#                   host_neighbourhood  latitude  longitude       property_type  \
# 0                            Midtown  40.75362  -73.98377           Apartment
# 1                             Harlem  40.80902  -73.94190           Apartment
# 2                       Clinton Hill  40.68514  -73.95976         Guest suite
# 3                        East Harlem  40.79851  -73.94399           Apartment
# 4                  Flatiron District  40.74767  -73.97500           Apartment
# 5                 Bedford-Stuyvesant  40.68688  -73.95596           Apartment
# 6                     Hell's Kitchen  40.76489  -73.98493           Apartment
# 7                    Upper West Side  40.80178  -73.96723           Apartment
# 8                      Alphabet City  40.72764  -73.97949           Apartment
# 9                    Lower East Side  40.71344  -73.99037           Apartment
# 10                   Upper West Side  40.80316  -73.96545           Apartment
# 11                      Times Square  40.76076  -73.98867           Apartment
# 12                        Park Slope  40.66829  -73.98779           Townhouse
# 13                      West Village  40.73530  -74.00525           Apartment
# 14                      Williamsburg  40.70837  -73.95352           Apartment
# 15                       Fort Greene  40.69169  -73.97185           Apartment
# 16                           Chelsea  40.74192  -73.99501           Apartment
# 17                     Crown Heights  40.67592  -73.94694           Townhouse
# 18                       East Harlem  40.79685  -73.94872           Apartment
# 19                      Williamsburg  40.71842  -73.95718                Loft
# 20                        Park Slope  40.68069  -73.97706   Bed and breakfast
# 21                        Park Slope  40.68001  -73.97865   Bed and breakfast
# 22                Bedford-Stuyvesant  40.68371  -73.94028                Loft
# 23                   Windsor Terrace  40.65599  -73.97519         Condominium
# 24                            Inwood  40.86754  -73.92639           Apartment
# 25                    Hell's Kitchen  40.76715  -73.98533           Apartment
# 26                      East Village  40.72920  -73.98542           Apartment
# 27                  Hamilton Heights  40.82245  -73.95104           Apartment
# 28                            Harlem  40.81305  -73.95466           Apartment
# 29                      Williamsburg  40.72219  -73.93762           Apartment
# ...                              ...       ...        ...                 ...
# 40150               Hamilton Heights  40.82051  -73.95291           Apartment
# 40151  Times Square/Theatre District  40.76015  -73.98497  Serviced apartment
# 40152                   Williamsburg  40.70298  -73.93834           Apartment
# 40153             Washington Heights  40.83325  -73.94444           Apartment
# 40154                   Williamsburg  40.71396  -73.93986           Apartment
# 40155                 Hell's Kitchen  40.76318  -73.99335           Apartment
# 40156                Lower East Side  40.72233  -73.99334           Apartment
# 40157                Upper East Side  40.77698  -73.95712           Apartment
# 40158                        Maspeth  40.73210  -73.89712           Apartment
# 40159                       Glendale  40.69271  -73.89519           Apartment
# 40160                            NaN  40.71268  -73.94720           Apartment
# 40161              Greenwich Village  40.73365  -73.99727           Apartment
# 40162                Upper West Side  40.79481  -73.97432           Apartment
# 40163                      Sunnyside  40.73641  -73.92415           Townhouse
# 40164                            NaN  40.70484  -73.91393           Apartment
# 40165                            NaN  40.82709  -73.91625           Apartment
# 40166                Upper West Side  40.78757  -73.97624           Apartment
# 40167             Bedford-Stuyvesant  40.67767  -73.91784           Apartment
# 40168                   Midtown East  40.75445  -73.96471           Apartment
# 40169             Bedford-Stuyvesant  40.68272  -73.92555           Apartment
# 40170                            NaN  40.74523  -73.83321               House
# 40171                            NaN  40.74588  -73.83284               House
# 40172                 Williamsbridge  40.87905  -73.85243         Guest suite
# 40173                            NaN  40.71214  -73.99643           Apartment
# 40174                            NaN  40.71247  -73.99619           Apartment
# 40175                            NaN  40.71208  -73.99410           Apartment
# 40176                        Midtown  40.74670  -73.98706           Apartment
# 40177               Prospect Heights  40.67743  -73.97202           Apartment
# 40178                            NaN  40.75204  -73.97278              Resort
# 40179                            NaN       NaN        NaN                 NaN
#
#              room_type  accommodates  \
# 0      Entire home/apt           2.0
# 1         Private room           2.0
# 2      Entire home/apt           3.0
# 3      Entire home/apt           1.0
# 4      Entire home/apt           2.0
# 5         Private room           2.0
# 6         Private room           2.0
# 7         Private room           1.0
# 8      Entire home/apt           2.0
# 9      Entire home/apt           3.0
# 10     Entire home/apt           2.0
# 11        Private room           2.0
# 12        Private room           2.0
# 13     Entire home/apt           1.0
# 14     Entire home/apt           3.0
# 15     Entire home/apt           4.0
# 16        Private room           3.0
# 17     Entire home/apt           4.0
# 18     Entire home/apt           4.0
# 19     Entire home/apt           4.0
# 20        Private room           4.0
# 21        Private room           3.0
# 22     Entire home/apt           5.0
# 23        Private room           2.0
# 24        Private room           2.0
# 25     Entire home/apt           2.0
# 26     Entire home/apt           3.0
# 27        Private room           2.0
# 28        Private room           2.0
# 29        Private room           2.0
# ...                ...           ...
# 40150     Private room           2.0
# 40151  Entire home/apt           7.0
# 40152     Private room           2.0
# 40153     Private room           2.0
# 40154  Entire home/apt           5.0
# 40155  Entire home/apt           2.0
# 40156     Private room           2.0
# 40157  Entire home/apt           8.0
# 40158     Private room           1.0
# 40159  Entire home/apt           6.0
# 40160     Private room           2.0
# 40161  Entire home/apt           3.0
# 40162  Entire home/apt           7.0
# 40163     Private room           1.0
# 40164     Private room           2.0
# 40165  Entire home/apt           2.0
# 40166      Shared room           1.0
# 40167     Private room           4.0
# 40168  Entire home/apt           3.0
# 40169  Entire home/apt           3.0
# 40170     Private room           2.0
# 40171     Private room           2.0
# 40172  Entire home/apt           2.0
# 40173     Private room           2.0
# 40174     Private room           2.0
# 40175     Private room           2.0
# 40176  Entire home/apt           3.0
# 40177  Entire home/apt           2.0
# 40178  Entire home/apt           4.0
# 40179              NaN           NaN
#
#                                                amenities     price  \
# 0      {TV,Wifi,"Air conditioning",Kitchen,"Paid park...  $225.00
# 1      {"Cable TV",Internet,Wifi,"Air conditioning",K...  $150.00
# 2      {TV,"Cable TV",Internet,Wifi,"Air conditioning...   $89.00
# 3      {Internet,Wifi,"Air conditioning",Kitchen,Elev...   $80.00
# 4      {TV,"Cable TV",Internet,Wifi,Kitchen,"Buzzer/w...  $200.00
# 5      {Wifi,"Air conditioning",Kitchen,"Pets live on...   $60.00
# 6      {TV,Wifi,"Air conditioning","Paid parking off ...   $79.00
# 7      {Internet,Wifi,"Air conditioning","Paid parkin...   $79.00
# 8      {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $116.00
# 9      {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  $150.00
# 10     {Internet,Wifi,"Air conditioning",Kitchen,Door...  $135.00
# 11     {Internet,Wifi,"Air conditioning",Breakfast,"B...   $85.00
# 12     {Internet,Wifi,"Air conditioning","Free street...   $89.00
# 13     {Wifi,"Air conditioning",Kitchen,Heating,"Smok...  $120.00
# 14     {TV,Wifi,"Air conditioning",Kitchen,"Free stre...  $140.00
# 15     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $215.00
# 16     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $140.00
# 17     {TV,Internet,Wifi,"Air conditioning",Kitchen,"...   $99.00
# 18     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $190.00
# 19     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $299.00
# 20     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $115.00
# 21     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $110.00
# 22     {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  $120.00
# 23     {Wifi,"Air conditioning","Free street parking"...   $60.00
# 24     {Internet,Wifi,Kitchen,"Paid parking off premi...   $80.00
# 25     {TV,Wifi,"Air conditioning",Kitchen,"Pets allo...  $150.00
# 26     {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $180.00
# 27     {Internet,Wifi,Pool,Kitchen,"Paid parking off ...   $50.00
# 28     {TV,"Cable TV",Internet,Wifi,"Air conditioning...   $52.00
# 29     {TV,Internet,Wifi,"Air conditioning",Kitchen,"...   $55.00
# ...                                                  ...       ...
# 40150  {Wifi,"Air conditioning",Kitchen,Gym,Breakfast...   $53.00
# 40151  {TV,Wifi,"Air conditioning",Kitchen,"Paid park...  $890.00
# 40152  {Wifi,Kitchen,Heating,"Smoke detector","Carbon...   $80.00
# 40153  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...   $50.00
# 40154  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  $179.00
# 40155  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $130.00
# 40156  {Wifi,"Air conditioning",Kitchen,"Fire extingu...   $85.00
# 40157  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...  $800.00
# 40158  {Wifi,"Air conditioning","Free street parking"...   $40.00
# 40159  {TV,Wifi,"Air conditioning",Kitchen,"Free park...  $135.00
# 40160  {TV,Wifi,"Air conditioning",Kitchen,Heating,"S...   $80.00
# 40161  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $159.00
# 40162  {TV,Wifi,"Air conditioning",Elevator,"Indoor f...  $150.00
# 40163  {Wifi,"Air conditioning",Kitchen,Breakfast,Hea...   $40.00
# 40164  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...   $59.00
# 40165  {TV,"Air conditioning",Kitchen,Heating,"Smoke ...   $65.00
# 40166  {"Air conditioning",Kitchen,Breakfast,"Indoor ...  $500.00
# 40167  {TV,Wifi,"Air conditioning","Free parking on p...  $100.00
# 40168  {TV,Wifi,"Air conditioning",Kitchen,"Paid park...  $159.00
# 40169  {Wifi,"Air conditioning",Kitchen,"Pets allowed...  $119.00
# 40170  {Wifi,"Air conditioning",Kitchen,"Hot tub",Hea...   $42.00
# 40171  {Wifi,"Air conditioning",Kitchen,"Hot tub",Hea...   $49.00
# 40172  {TV,Wifi,"Air conditioning",Kitchen,"Pets allo...   $76.00
# 40173  {Wifi,"Air conditioning",Kitchen,"Free parking...   $97.00
# 40174  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...  $300.00
# 40175  {Wifi,"Air conditioning",Kitchen,"Free street ...   $93.00
# 40176  {TV,Wifi,"Air conditioning",Kitchen,Elevator,H...  $220.00
# 40177  {TV,Wifi,Kitchen,"Pets allowed",Heating,Washer...  $175.00
# 40178  {TV,"Cable TV",Internet,Wifi,"Air conditioning...  $699.00
# 40179                                                NaN       NaN
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0                 288.0               46.0                   12.0
# 1                 365.0                0.0                    0.0
# 2                 212.0              274.0                   70.0
# 3                   0.0                9.0                    2.0
# 4                 127.0               75.0                   10.0
# 5                   0.0               49.0                    0.0
# 6                 239.0              434.0                   44.0
# 7                   0.0              118.0                    0.0
# 8                 322.0               94.0                    0.0
# 9                   0.0              161.0                   13.0
# 10                  1.0               53.0                   14.0
# 11                 23.0              190.0                   32.0
# 12                324.0              167.0                   12.0
# 13                  4.0               27.0                    1.0
# 14                 23.0              154.0                   54.0
# 15                305.0              200.0                   39.0
# 16                  5.0              268.0                   29.0
# 17                 22.0               59.0                   55.0
# 18                275.0                0.0                    0.0
# 19                  0.0                9.0                    0.0
# 20                117.0              131.0                   18.0
# 21                290.0               73.0                   18.0
# 22                251.0               92.0                   27.0
# 23                 89.0               20.0                   17.0
# 24                  0.0                0.0                    0.0
# 25                104.0               58.0                    0.0
# 26                 42.0               29.0                    7.0
# 27                341.0              244.0                   22.0
# 28                252.0               92.0                   21.0
# 29                309.0              201.0                   23.0
# ...                 ...                ...                    ...
# 40150               1.0                5.0                    5.0
# 40151             312.0                2.0                    2.0
# 40152              34.0                0.0                    0.0
# 40153              50.0               11.0                   11.0
# 40154              17.0               11.0                   11.0
# 40155             292.0                2.0                    2.0
# 40156               8.0               22.0                   22.0
# 40157             106.0                4.0                    4.0
# 40158             140.0                1.0                    1.0
# 40159              97.0                9.0                    9.0
# 40160              81.0               13.0                   13.0
# 40161              90.0                0.0                    0.0
# 40162             273.0               26.0                   26.0
# 40163             216.0                6.0                    6.0
# 40164              72.0               26.0                   26.0
# 40165              20.0                0.0                    0.0
# 40166              89.0                0.0                    0.0
# 40167             365.0                7.0                    7.0
# 40168             246.0                0.0                    0.0
# 40169               9.0               13.0                   13.0
# 40170             156.0               23.0                   23.0
# 40171             138.0               22.0                   22.0
# 40172             331.0               19.0                   19.0
# 40173             161.0               35.0                   35.0
# 40174             139.0               25.0                   25.0
# 40175             363.0               32.0                   32.0
# 40176             287.0                6.0                    6.0
# 40177             309.0                0.0                    0.0
# 40178             113.0                0.0                    0.0
# 40179               NaN                NaN                    NaN
#
#        review_scores_rating  review_scores_location  reviews_per_month
# 0                      95.0                    10.0               0.39
# 1                       NaN                     NaN                NaN
# 2                      90.0                    10.0               4.64
# 3                      93.0                     9.0               0.10
# 4                      89.0                     9.0               0.60
# 5                      90.0                     9.0               0.39
# 6                      84.0                    10.0               3.48
# 7                      98.0                    10.0               0.98
# 8                      95.0                    10.0               0.74
# 9                      94.0                     9.0               1.33
# 10                     93.0                     9.0               0.42
# 11                     97.0                    10.0               1.50
# 12                     94.0                    10.0               1.33
# 13                     97.0                    10.0               0.22
# 14                     91.0                     9.0               1.24
# 15                     97.0                    10.0               1.72
# 16                     96.0                    10.0               2.17
# 17                     96.0                    10.0               4.59
# 18                      NaN                     NaN                NaN
# 19                     98.0                    10.0               0.07
# 20                     93.0                    10.0               1.09
# 21                     91.0                    10.0               0.63
# 22                     95.0                     9.0               0.76
# 23                     97.0                    10.0               1.35
# 24                      NaN                     NaN                NaN
# 25                     90.0                    10.0               0.48
# 26                     93.0                    10.0               0.24
# 27                     87.0                     9.0               2.04
# 28                     98.0                    10.0               1.46
# 29                     81.0                     9.0               1.67
# ...                     ...                     ...                ...
# 40150                  96.0                     9.0               0.88
# 40151                 100.0                    10.0               0.34
# 40152                   NaN                     NaN                NaN
# 40153                  96.0                    10.0               2.84
# 40154                  96.0                    10.0               2.31
# 40155                 100.0                    10.0               0.41
# 40156                  84.0                     9.0               3.91
# 40157                 100.0                    10.0               0.90
# 40158                 100.0                     8.0               1.00
# 40159                 100.0                    10.0               2.01
# 40160                 100.0                    10.0               3.05
# 40161                   NaN                     NaN                NaN
# 40162                  87.0                    10.0               4.41
# 40163                  93.0                    10.0               1.22
# 40164                  95.0                     9.0               4.36
# 40165                   NaN                     NaN                NaN
# 40166                   NaN                     NaN                NaN
# 40167                  91.0                     9.0               1.47
# 40168                   NaN                     NaN                NaN
# 40169                 100.0                     9.0               2.38
# 40170                  88.0                     9.0               4.06
# 40171                  97.0                     9.0               3.65
# 40172                  97.0                     9.0               3.35
# 40173                  94.0                    10.0               5.74
# 40174                  93.0                     9.0               4.29
# 40175                  88.0                     9.0               5.27
# 40176                  87.0                    10.0               1.29
# 40177                   NaN                     NaN                NaN
# 40178                   NaN                     NaN                NaN
# 40179                   NaN                     NaN                NaN
#
# [40180 rows x 14 columns]
